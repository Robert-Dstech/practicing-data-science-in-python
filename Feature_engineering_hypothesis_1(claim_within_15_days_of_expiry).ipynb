# %% [markdown]
# <a href="https://colab.research.google.com/github/Robert-Dstech/Data-science-/blob/main/Feature_engineering_hypothesis_1(claim_within_15_days_of_expiry).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path='/content/drive/MyDrive/AutoInsClaims.csv'

# %%
df=pd.read_csv(path)

# %%
EXPIRY_days= pd.to_datetime(df["EXPIRY_DATE"])

# %%
loss_event_time=pd.to_datetime(df["LOSS_EVENT_TIME"])

# %%
days_from_loss=(loss_event_time-EXPIRY_days)

# %%
CLEAN_DAYS=abs(days_from_loss)

# %%
df['CLEANER']=CLEAN_DAYS

# %%
df4=df.assign(CLEAN_DAYS=CLEAN_DAYS)

# %%
df4
# Out:
#     HOUSEHOLD_ID DRIVER_ID  POLICY_ID      CLAIM_ID  INCIDENT_CAUSE  \
# 0        CH42335   XZJ2837  NW5567882  A-2017-UU907               3
# 1              0         0          0             0               0
# 2        AF28736   UQM2512  RR8595908  A-2016-ZG694               1
# 3        EF53594   YDT5591  RN5640634  A-2016-NG783               1
# 4              0         0          0             0               0
# ..           ...       ...        ...           ...             ...
# 970      CM11612   GJI9724  QY3512250  A-2016-TJ210               3
# 971            0         0          0             0               0
# 972      BA79937   BLV8655  TU0769843  A-2016-MT971               1
# 973            0         0          0             0               0
# 974            0         0          0             0               0
#
#      DESCRIPTION  CLAIM_STATUS  ODOMETER_AT_LOSS LOSS_EVENT_TIME  \
# 0            NaN             1          157654.9         4/25/17
# ...
