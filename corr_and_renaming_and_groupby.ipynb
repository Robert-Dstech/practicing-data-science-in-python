# %% [markdown]
# <a href="https://colab.research.google.com/github/Robert-Dstech/Data-science-/blob/main/corr_and_renaming_and_groupby.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import pandas as pd

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path='/content/drive/MyDrive/AutoInsClaims.csv'

# %%
df=pd.read_csv(path)

# %%
df.columns
# Out:
# Index(['HOUSEHOLD_ID', 'DRIVER_ID', 'POLICY_ID', 'CLAIM_ID', 'INCIDENT_CAUSE',
#        'DESCRIPTION', 'CLAIM_STATUS', 'ODOMETER_AT_LOSS', 'LOSS_EVENT_TIME',
#        'CLAIM_INIT_TIME', 'POLICE_REPORT', 'CLAIMS_AT_LOSS_DATE',
#        'LOSS_LOCATION_LAT', 'LOSS_LOCATION_LONG', 'CLAIM_AMOUNT',
#        'FLAG_FOR_FRAUD_INV', 'PRIMARY_DRIVER_ID', 'START_DATE', 'EXPIRY_DATE',
#        'MODEL_YEAR', 'MAKE', 'MODEL', 'PLATE', 'COLOR', 'INITIAL_ODOMETER',
#        'LOW_MILEAGE_USE', 'FIRST_NAME', 'LAST_NAME', 'GENDER', 'BIRTHDATE',
#        'SSN', 'DRIVERS_LICENSE_ID', 'DRIVERS_LICENSE_EXPIRY',
#        'DRIVERS_LICENSE_STATE', 'DATE_AT_CURRENT_ADDRESS', 'CONTACT_NUMBER',
#        'EMAIL', 'COMMUTE_DISCOUNT'],
#       dtype='object')

# %%
df['DESCRIPTION'].corr(df['LOSS_EVENT_TIME'])
# Out:
# nan

# %%
r=df.rename(columns={"DRIVER_ID": "ivy", "CLAIM_ID": "MUTURI"})

# %%
df.corr()
# Out:
#                      INCIDENT_CAUSE  DESCRIPTION  CLAIM_STATUS  \
# INCIDENT_CAUSE             1.000000          NaN     -0.026115
# DESCRIPTION                     NaN          NaN           NaN
# CLAIM_STATUS              -0.026115          NaN      1.000000
# ODOMETER_AT_LOSS          -0.003935          NaN      0.013058
# POLICE_REPORT              0.101703          NaN     -0.327821
# CLAIMS_AT_LOSS_DATE       -0.006460          NaN     -0.114943
# LOSS_LOCATION_LAT          0.025496          NaN     -0.015531
# LOSS_LOCATION_LONG        -0.027283          NaN      0.028557
# CLAIM_AMOUNT               0.045416          NaN     -0.792106
# FLAG_FOR_FRAUD_INV         0.037962          NaN     -0.927869
# MODEL_YEAR                -0.009213          NaN     -0.016157
# INITIAL_ODOMETER          -0.002082          NaN      0.012986
# LOW_MILEAGE_USE            0.017236          NaN      0.008105
# COMMUTE_DISCOUNT          -0.012849          NaN      0.044860
#
# ...

# %%
path="/content/drive/MyDrive/updated sample.csv"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.read_csv(path)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'First Name', 'Last Name', 'Gender', 'Country', 'Age',
#        'Date', 'Id'],
#       dtype='object')

# %%
df2=df.groupby('First Name')[['Age']].mean()

# %%
df2
# Out:
#              Age
# First Name
# Angel       24.0
# Angelyn     29.0
# Arcelia     39.0
# Belinda     37.0
# Carla       28.0
# Chase       37.0
# Demetria    32.0
# Dewitt      36.0
# Dorcas      37.0
# Dulce       32.0
# Earlean     27.0
# Etta        56.0
# Fallon      28.0
# Felisa      28.0
# Francesca   23.0
# Franklyn    38.0
# Garth       41.0
# Gaston      24.0
# Holly       52.0
# Jeromy      39.0
# Jona        26.0
# Judie       35.0
# Kathleen    25.0
# Kelsie      27.0
# Kina        31.0
# Lauralee    28.0
# Lester      21.0
# Libbie      42.0
# Loreta      26.0
# Many        46.0
# Mara        25.0
# Marcel      26.0
# Marvel      28.0
# Nena        29.0
# Nereida     58.0
# Philip      36.0
# Rasheeda    29.0
# Roma        34.0
# Sau         25.0
# Shanice     36.0
# Shavon      39.0
# Shavonne    24.0
# Sherron     32.0
# Stasia      34.0
# Teresa      46.0
# Tommie      26.0
# Veta        37.0
# Vincenza    40.0
# Weston      26.0
# Willodean   39.0

# %%
df.groupby(['Age'])
